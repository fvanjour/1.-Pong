# %%
import turtle

def create_players():
    
    # Create player 1
    player1 = turtle.Turtle()
    player1.shape("square")
    player1.shapesize(stretch_wid=2, stretch_len=1, outline=1)
    player1.color("black")
    player1.up()
    player1.goto(150, 0)
    
    # Create player 2
    player2 = turtle.Turtle()
    player2.shape("square")
    player2.shapesize(stretch_wid=2, stretch_len=1, outline=1)
    player2.color("red")
    player2.up()
    player2.goto(-150, 0)
    # Return both players
    return player1, player2

def initiate_ball():
    
    # Create ball
    ball = turtle.Turtle()
    ball.shape("circle")
    ball.color("green")
    ball.up()
    ball.screen.exitonclick()
    ball.screen.title("Pong")
    ball.screen.delay(2000)
    
    # Return ball
    return ball

def create_walls():
    
    # upper wall
    wall_up = turtle.Turtle()
    wall_up.up()
    wall_up.shape("square")
    wall_up.shapesize(stretch_wid=1, stretch_len=30, outline=1)
    wall_up.color("red")
    wall_up.goto(0,100)
    
    # lower wall
    wall_down = turtle.Turtle()
    wall_down.up()
    wall_down.shape("square")
    wall_down.shapesize(stretch_wid=1, stretch_len=30, outline=1)
    wall_down.color("red")
    wall_down.goto(0,-100)
    
    return wall_up, wall_down


def create_goals():
    
    # left goal
    goal_left = turtle.Turtle()
    goal_left.up()
    goal_left.shape("square")
    goal_left.shapesize(stretch_wid=30, stretch_len=1, outline=1)
    goal_left.color("red")
    goal_left.goto(200,0)
    
    # right goal
    goal_right = turtle.Turtle()
    goal_right.up()
    goal_right.shape("square")
    goal_right.shapesize(stretch_wid=30, stretch_len=1, outline=1)
    goal_right.color("red")
    goal_right.goto(-200,0)
    
    return goal_left, goal_right
    pass

def move_ball(ball):
    # Move ball
    ball.forward(5)
    
moves_left = False

wall_up, wall_down = create_walls()

goal_left, goal_right = create_goals()

player1, player2 = create_players()

ball = initiate_ball()

for i in range(20):
    move_ball(ball)
    

#start_moving_ball(ball, player1.xcor()-20, player1.ycor())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 89
#      85 goal_left, goal_right = create_goals()
#      87 player1, player2 = create_players()
# ---> 89 ball = initiate_ball()
#      91 for i in range(20):
#      92     move_ball(ball)
#
# Cell In[1], line 30, in initiate_ball()
#      28 ball.color("green")
#      29 ball.up()
# ---> 30 ball.delay(100)
#      32 # Return ball
#      33 return ball
#
# AttributeError: 'Turtle' object has no attribute 'delay'
